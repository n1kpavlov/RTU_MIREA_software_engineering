# %% [markdown]
# Задание 1: Создайте класс по работе с тригонометрическими функциями. В классе
# должны быть реализованы функции вычисления:
# − косинуса;
# − синуса;
# − тангенса;
# − арксинуса;
# − арккосинуса;
# − арктангенса;
# − перевода из градусов в радианы

# %%
import math

class TrigonometricFunctions:
    def __init__(self):
        pass

    def _cos_(self, angle):
        return math.cos(math.radians(angle))

    def _sin_(self, angle):
        return math.sin(math.radians(angle))

    def _tan_(self, angle):
        return math.tan(math.radians(angle))

    def _arcsin_(self, value):
        return math.degrees(math.asin(value))

    def _arccos_(self, value):
        return math.degrees(math.acos(value))

    def _arctan_(self, value):
        return math.degrees(math.atan(value))

    def degrees_to_radians(self, degrees):
        return math.radians(degrees)

a = TrigonometricFunctions
print(a._cos_(a, 0))
print(a._sin_(a, 90))
print(a._tan_(a, 45))
print(a._arccos_(a, 1))
print(a._arcsin_(a, 1))
print(a._arctan_(a, 1))
print(a.degrees_to_radians(a, 34))
# Out:
# 1.0
# 1.0
# 0.9999999999999999
# 0.0
# 90.0
# 45.0
# 0.5934119456780721

# %% [markdown]
# Задание 2: Представьте дерево показанное на рисунке с использованием списка из
# списков. Выведите на печать корень дерева, а также его левое и правое
# поддеревья

# %%
tree = ['A', ['B', ['D'], ['E']], ['C', ['F']]]

root = tree[0]
left_subtree = tree[1]
right_subtree = tree[2]

print("Root of the tree:", root)
print("Left subtree:", left_subtree)
print("Right subtree:", right_subtree)
# Out:
# Root of the tree: A
# Left subtree: ['B', ['D'], ['E']]
# Right subtree: ['C', ['F']]

# %% [markdown]
# Задание 3: Дан класс, описывающий бинарное дерево.
# class Tree:
#  def __init__(self, data):
#  self.left = None
#  self.right = None
#  self.data = data
#  def PrintTree(self):
#  print(self.data)
# Реализуйте в классе функцию для вставки нового элемента в дерево по
# следующим правилам:
# • Левое поддерево узла содержит только узлы со значениями меньше,
# чем значение в узле.
# • Правое поддерево узла содержит только узлы со значениями меньше,
# чем значение в узле.
# • Каждое из левого и правого поддеревьев также должно быть
# бинарным деревом поиска.
# • Не должно быть повторяющихся узлов.
# Метод вставки сравнивает значение узла с родительским узлом и решает
# куда доваить элемент (в левое или правое поддерево). Перепишите, метод
# PrintTree для печати полной версии дерева.

# %%
class Tree:
  def __init__(self, data):
    self.left = None
    self.right = None
    self.data = data

  def PrintTree(self):
    print(self.data)

  def insert(self, value):
    if value < self.data:
      if self.left is None:
        self.left = Tree(value)
      else:
        self.left.insert(value)
    elif value > self.data:
      if self.right is None:
        self.right = Tree(value)
      else:
        self.right.insert(value)

  def PrintFullTree(self):
    if self.left:
      print("left")
      self.left.PrintFullTree()
    print(self.data)
    if self.right:
      print("right")
      self.right.PrintFullTree()

tree = Tree(50)
tree.insert(30)
tree.insert(50)
tree.insert(50)
tree.insert(13)
tree.insert(58)
tree.insert(5)
tree.insert(67)
tree.insert(7)
tree.insert(54)
tree.PrintFullTree()
# Out:
# left
# left
# left
# 5
# right
# 7
# 13
# 30
# 50
# right
# left
# 54
# 58
# right
# 67

# %% [markdown]
# Задание 4:Постройте классификатор на основе дерева принятия решений
# следующего датасета:
# x = [[-1,-1], [-2, -1], [-3, -2], [1,1], [2,1], [3,2]]
# target = [0,0,0,1,1,1]

# %%
from sklearn import tree

x = [[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]]
target = [0, 0, 0, 1, 1, 1]

clf = tree.DecisionTreeClassifier()
clf = clf.fit(x, target)

tree.plot_tree(clf)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 0.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %% [markdown]
# Задание 5: Задание. Постройте модель регрессии для данных из предыдущей рабочей
# тетради.Для примера можно взять потребления газа (в миллионах
# галлонов) в 48 штатах США или набор данных о качестве красного вина:
# https://raw.githubusercontent.com/likarajo/petrol_consumption/master/data/petrol_consumption.csv
# https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv
# Постройте прогноз. Оцените точность модели

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from pandas import DataFrame, Series
from sklearn import metrics

url = 'https://raw.githubusercontent.com/likarajo/petrol_consumption/master/data/petrol_consumption.csv'
ds = pd.read_csv(url)

X = ds[['Petrol_tax', 'Average_income', 'Paved_Highways', 'Population_Driver_licence(%)']]
Y = ds['Petrol_Consumption']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

rgs = DecisionTreeRegressor()
rgs.fit(x_train, y_train)

tree.plot_tree(rgs)
plt.show()

y_pred = rgs.predict(x_test)
data = pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
print(data)

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred))
print(metrics.mean_absolute_error(y_test, y_pred) / np.average(Y) * 100)
# Out:
#     Actual  Predicted
# 29     534      541.0
# 4      410      414.0
# 26     577      574.0
# 30     571      554.0
# 32     577      631.0
# 37     704      644.0
# 34     487      628.0
# 40     587      649.0
# 7      467      414.0
# 10     580      498.0
# Mean Squared Error:  4013.7
# Mean Absolute Error:  48.3
# 8.374209860935524
